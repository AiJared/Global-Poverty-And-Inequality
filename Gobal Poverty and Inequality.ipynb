# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Enable display of all columns
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
data_info = pd.read_csv("pip_codebook.csv")
data_info
# Out:
#                                          column  \
# 0                                       country
# 1                                          year
# 2                               reporting_level
# 3                                  welfare_type
# 4                                   ppp_version
# 5                                   survey_year
# 6                          survey_comparability
# 7         headcount_ratio_international_povline
# 8      headcount_ratio_lower_mid_income_povline
# 9      headcount_ratio_upper_mid_income_povline
# 10                          headcount_ratio_100
# 11                         headcount_ratio_1000
# 12                         headcount_ratio_2000
# 13                         headcount_ratio_3000
# 14                         headcount_ratio_4000
# 15                    headcount_ratio_40_median
# 16                    headcount_ratio_50_median
# 17                    headcount_ratio_60_median
# 18              headcount_international_povline
# 19           headcount_lower_mid_income_povline
# 20           headcount_upper_mid_income_povline
# 21                                headcount_100
# 22                               headcount_1000
# 23                               headcount_2000
# 24                               headcount_3000
# 25                               headcount_4000
# 26                          headcount_40_median
# 27                          headcount_50_median
# 28                          headcount_60_median
# 29          avg_shortfall_international_povline
# 30       avg_shortfall_lower_mid_income_povline
# 31       avg_shortfall_upper_mid_income_povline
# 32                            avg_shortfall_100
# 33                           avg_shortfall_1000
# 34                           avg_shortfall_2000
# 35                           avg_shortfall_3000
# 36                           avg_shortfall_4000
# 37                      avg_shortfall_40_median
# 38                      avg_shortfall_50_median
# 39                      avg_shortfall_60_median
# 40        total_shortfall_international_povline
# 41     total_shortfall_lower_mid_income_povline
# 42     total_shortfall_upper_mid_income_povline
# 43                          total_shortfall_100
# 44                         total_shortfall_1000
# 45                         total_shortfall_2000
# 46                         total_shortfall_3000
# 47                         total_shortfall_4000
# 48                    total_shortfall_40_median
# 49                    total_shortfall_50_median
# 50                    total_shortfall_60_median
# 51       income_gap_ratio_international_povline
# 52    income_gap_ratio_lower_mid_income_povline
# 53    income_gap_ratio_upper_mid_income_povline
# 54                         income_gap_ratio_100
# 55                        income_gap_ratio_1000
# 56                        income_gap_ratio_2000
# 57                        income_gap_ratio_3000
# 58                        income_gap_ratio_4000
# 59                   income_gap_ratio_40_median
# 60                   income_gap_ratio_50_median
# 61                   income_gap_ratio_60_median
# 62      poverty_gap_index_international_povline
# 63   poverty_gap_index_lower_mid_income_povline
# 64   poverty_gap_index_upper_mid_income_povline
# 65                        poverty_gap_index_100
# 66                       poverty_gap_index_1000
# 67                       poverty_gap_index_2000
# 68                       poverty_gap_index_3000
# 69                       poverty_gap_index_4000
# 70                                         mean
# 71                                       median
# 72                                  decile1_avg
# 73                                  decile2_avg
# 74                                  decile3_avg
# 75                                  decile4_avg
# 76                                  decile5_avg
# 77                                  decile6_avg
# 78                                  decile7_avg
# 79                                  decile8_avg
# 80                                  decile9_avg
# 81                                 decile10_avg
# 82                                decile1_share
# 83                                decile2_share
# 84                                decile3_share
# 85                                decile4_share
# 86                                decile5_share
# 87                                decile6_share
# 88                                decile7_share
# 89                                decile8_share
# 90                                decile9_share
# 91                               decile10_share
# 92                                  decile1_thr
# 93                                  decile2_thr
# 94                                  decile3_thr
# 95                                  decile4_thr
# 96                                  decile6_thr
# 97                                  decile7_thr
# 98                                  decile8_thr
# 99                                  decile9_thr
# 100                                        gini
# 101                                         mld
# 102                                polarization
# 103                                 palma_ratio
# 104                               s80_s20_ratio
# 105                               p90_p10_ratio
# 106                               p90_p50_ratio
# 107                               p50_p10_ratio
#
#                                            description
# 0    The name of the country to which the row relat...
# 1    The following description is adapted from PIP ...
# 2    The reporting level of the survey. It can be n...
# 3    Indicates whether the survey data relates to h...
# 4    The version of the Purchasing Power Parity (PP...
# 5    The following description is adapted from PIP ...
# 6    A variable produced by the World Bank that cod...
# 7    % of population living in households with an i...
# 8    % of population living in households with an i...
# 9    % of population living in households with an i...
# 10   % of population living in households with an i...
# 11   % of population living in households with an i...
# 12   % of population living in households with an i...
# 13   % of population living in households with an i...
# 14   % of population living in households with an i...
# 15   % of population living in households with an i...
# 16   % of population living in households with an i...
# 17   % of population living in households with an i...
# 18   Number of people living in households with an ...
# 19   Number of people living in households with an ...
# 20   Number of people living in households with an ...
# 21   Number of people living in households with an ...
# 22   Number of people living in households with an ...
# 23   Number of people living in households with an ...
# 24   Number of people living in households with an ...
# 25   Number of people living in households with an ...
# 26   Number of people living in households with an ...
# 27   Number of people living in households with an ...
# 28   Number of people living in households with an ...
# 29   The average shortfall from the International P...
# 30   The average shortfall from the lower-middle in...
# 31   The average shortfall from the upper-middle in...
# 32   The average shortfall from the poverty line of...
# 33   The average shortfall from the poverty line of...
# 34   The average shortfall from the poverty line of...
# 35   The average shortfall from the poverty line of...
# 36   The average shortfall from the poverty line of...
# 37   The average shortfall from a poverty line of t...
# 38   The average shortfall from a poverty line of t...
# 39   The average shortfall from a poverty line of t...
# 40   The total shortfall from the International Pov...
# 41   The total shortfall from the lower-middle inco...
# 42   The total shortfall from the upper-middle inco...
# 43   The total shortfall from a poverty line of $1 ...
# 44   The total shortfall from a poverty line of $10...
# 45   The total shortfall from a poverty line of $20...
# 46   The total shortfall from a poverty line of $30...
# 47   The total shortfall from a poverty line of $40...
# 48   The total shortfall from a poverty line of the...
# 49   The total shortfall from a poverty line of the...
# 50   The total shortfall from a poverty line of the...
# 51   The average shortfall from the International P...
# 52   The average shortfall from the lower-middle in...
# 53   The average shortfall from the upper-middle in...
# 54   The average shortfall from a poverty line of $...
# 55   The average shortfall from a poverty line of $...
# 56   The average shortfall from a poverty line of $...
# 57   The average shortfall from a poverty line of $...
# 58   The average shortfall from a poverty line of $...
# 59   The average shortfall from a poverty line of t...
# 60   The average shortfall from a poverty line of t...
# 61   The average shortfall from a poverty line of t...
# 62   The poverty gap index calculated at the Intern...
# 63   The poverty gap index calculated at the lower-...
# 64   The poverty gap index calculated atthe upper-m...
# 65   The poverty gap index calculated at a poverty ...
# 66   The poverty gap index calculated at a poverty ...
# 67   The poverty gap index calculated at a poverty ...
# 68   The poverty gap index calculated at a poverty ...
# 69   The poverty gap index calculated at a poverty ...
# 70    The mean level of income or expenditure per day.
# 71   The level of income or expenditure per day bel...
# 72   The mean income or expenditure per day within ...
# 73   The mean income or expenditure per day within ...
# 74   The mean income or expenditure per day within ...
# 75   The mean income or expenditure per day within ...
# 76   The mean income or expenditure per day within ...
# 77   The mean income or expenditure per day within ...
# 78   The mean income or expenditure per day within ...
# 79   The mean income or expenditure per day within ...
# 80   The mean income or expenditure per day within ...
# 81   The mean income or expenditure per day within ...
# 82   The income or expenditure of the poorest decil...
# 83   The income or expenditure of the 2nd decile (t...
# 84   The income or expenditure of the 3rd decile (t...
# 85   The income or expenditure of the 4th decile (t...
# 86   The income or expenditure of the 5th decile (t...
# 87   The income or expenditure of the 6th decile (t...
# 88   The income or expenditure of the 7th decile (t...
# 89   The income or expenditure of the 8th decile (t...
# 90   The income or expenditure of the 9th decile (t...
# 91   The income or expenditure of the richest decil...
# 92   The level of income or expenditure per day bel...
# 93   The level of income or expenditure per day bel...
# 94   The level of income or expenditure per day bel...
# 95   The level of income or expenditure per day bel...
# 96   The level of income or expenditure per day bel...
# 97   The level of income or expenditure per day bel...
# 98   The level of income or expenditure per day bel...
# 99   The level of income or expenditure per day bel...
# 100  The Gini coefficient measures inequality on a ...
# 101  The mean log deviation (MLD) is a measure of i...
# 102  The polarization index, also known as the Wolf...
# 103  The Palma ratio is a measure of inequality: it...
# 104  The share of total income (or expenditure) of ...
# 105  P90 is the the level of income or expenditure ...
# 106  P90 is the the level of income or expenditure ...
# 107  P50 is the median – the level of income or exp...

# %%
# load the dataset
dataset = pd.read_csv("pip_dataset.csv")
df = pd.DataFrame(dataset)
df.head()
# Out:
#    country  year reporting_level welfare_type  ppp_version  survey_year  \
# 0  Albania  1996        national  consumption         2011       1996.0
# 1  Albania  2002        national  consumption         2011       2002.0
# 2  Albania  2005        national  consumption         2011       2005.0
# 3  Albania  2008        national  consumption         2011       2008.0
# 4  Albania  2012        national  consumption         2011       2012.0
#
#    survey_comparability  headcount_ratio_international_povline  \
# 0                   0.0                               0.920669
# 1                   1.0                               1.570843
# 2                   1.0                               0.860527
# 3                   1.0                               0.313650
# 4                   1.0                               0.849754
#
#    headcount_ratio_lower_mid_income_povline  \
# 0                                 11.174149
# 1                                 14.132118
# 2                                  8.715685
# 3                                  5.250542
# 4                                  6.182414
#
#    headcount_ratio_upper_mid_income_povline  headcount_ratio_100  \
# 0                                 44.618417             0.057416
# 1                                 49.669635             0.046371
# 2                                 38.545254             0.027620
# 3                                 31.110345             0.000000
# 4                                 34.528906             0.111321
#
#    headcount_ratio_1000  headcount_ratio_2000  headcount_ratio_3000  \
# 0             86.175208             99.632079             99.912465
# 1             85.338317             98.080061             99.638386
# 2             79.987127             97.576598             99.434458
# 3             75.851021             97.099785             99.015864
# 4             77.069840             97.772626             99.618299
#
#    headcount_ratio_4000  headcount_ratio_40_median  headcount_ratio_50_median  \
# 0             99.951656                   2.768821                   7.548123
# 1             99.843081                   3.212283                   8.406373
# 2             99.751744                   4.095002                   8.991533
# 3             99.678248                   2.118535                   7.227714
# 4             99.885984                   3.492413                   7.753112
#
#    headcount_ratio_60_median  headcount_international_povline  \
# 0                  14.802514                          29167.0
# 1                  16.020554                          47927.0
# 2                  16.675770                          25915.0
# 3                  14.137154                           9244.0
# 4                  14.842823                          24646.0
#
#    headcount_lower_mid_income_povline  headcount_upper_mid_income_povline  \
# 0                            354001.0                           1413526.0
# 1                            431172.0                           1515426.0
# 2                            262472.0                           1160785.0
# 3                            154750.0                            916920.0
# 4                            179315.0                           1001477.0
#
#    headcount_100  headcount_1000  headcount_2000  headcount_3000  \
# 0         1819.0       2730059.0       3156377.0       3165260.0
# 1         1415.0       2603681.0       2992432.0       3039977.0
# 2          832.0       2408802.0       2938507.0       2994456.0
# 3            0.0       2235568.0       2861836.0       2918308.0
# 4         3229.0       2235334.0       2835798.0       2889330.0
#
#    headcount_4000  headcount_40_median  headcount_50_median  \
# 0       3166501.0              87717.0             239127.0
# 1       3046222.0              98007.0             256479.0
# 2       3004011.0             123320.0             270779.0
# 3       2937831.0              62440.0             213023.0
# 4       2897094.0             101294.0             224871.0
#
#    headcount_60_median  avg_shortfall_international_povline  \
# 0             468949.0                             0.289026
# 1             488789.0                             0.316608
# 2             502189.0                             0.289956
# 3             416666.0                             0.310412
# 4             430501.0                             0.378104
#
#    avg_shortfall_lower_mid_income_povline  \
# 0                                0.599908
# 1                                0.646679
# 2                                0.646771
# 3                                0.457728
# 4                                0.658698
#
#    avg_shortfall_upper_mid_income_povline  avg_shortfall_100  \
# 0                                1.583098           0.204227
# 1                                1.671541           0.535089
# 2                                1.514365           0.008328
# 3                                1.307345                NaN
# 4                                1.377123           0.107417
#
#    avg_shortfall_1000  avg_shortfall_2000  avg_shortfall_3000  \
# 0            4.459419           13.504298           23.459160
# 1            4.719031           13.701617           23.422400
# 2            4.228461           12.918565           22.611586
# 3            3.881222           12.363527           22.069747
# 4            4.030469           12.546081           22.246319
#
#    avg_shortfall_4000  avg_shortfall_40_median  avg_shortfall_50_median  \
# 0           33.448817                 0.344615                 0.498115
# 1           33.368256                 0.385498                 0.517796
# 2           32.524793                 0.436059                 0.656600
# 3           31.895596                 0.429575                 0.574861
# 4           32.175593                 0.543789                 0.714691
#
#    avg_shortfall_60_median  total_shortfall_international_povline  \
# 0                 0.684516                            8430.020299
# 1                 0.685953                           15174.078091
# 2                 0.851665                            7514.215015
# 3                 0.803073                            2869.449485
# 4                 0.888404                            9318.745929
#
#    total_shortfall_lower_mid_income_povline  \
# 0                             212367.880904
# 1                             278829.871427
# 2                             169759.345273
# 3                              70833.376057
# 4                             118114.457301
#
#    total_shortfall_upper_mid_income_povline  total_shortfall_100  \
# 0                              2.237750e+06           371.488565
# 1                              2.533096e+06           757.151389
# 2                              1.757852e+06             6.929046
# 3                              1.198731e+06             0.000000
# 4                              1.379157e+06           346.848655
#
#    total_shortfall_1000  total_shortfall_2000  total_shortfall_3000  \
# 0          1.217448e+07          4.262466e+07          7.425434e+07
# 1          1.228685e+07          4.100116e+07          7.120356e+07
# 2          1.018553e+07          3.796129e+07          6.770940e+07
# 3          8.676735e+06          3.538239e+07          6.440632e+07
# 4          9.009444e+06          3.557815e+07          6.427696e+07
#
#    total_shortfall_4000  total_shortfall_40_median  total_shortfall_50_median  \
# 0          1.059157e+08               30228.591280              119112.664178
# 1          1.016471e+08               37781.498485              132803.796424
# 2          9.770483e+07               53774.749247              177793.358008
# 3          9.370387e+07               26822.633470              122458.630794
# 4          9.321572e+07               55082.529075              160713.189100
#
#    total_shortfall_60_median  income_gap_ratio_international_povline  \
# 0              321003.035619                               15.211893
# 1              335286.119897                               16.663586
# 2              427696.600510                               15.260853
# 3              334613.077611                               16.337479
# 4              382458.939593                               19.900199
#
#    income_gap_ratio_lower_mid_income_povline  \
# 0                                  18.747112
# 1                                  20.208718
# 2                                  20.211602
# 3                                  14.303994
# 4                                  20.584317
#
#    income_gap_ratio_upper_mid_income_povline  income_gap_ratio_100  \
# 0                                  28.783601             20.422681
# 1                                  30.391649             53.508932
# 2                                  27.533901              0.832818
# 3                                  23.769914                   NaN
# 4                                  25.038593             10.741674
#
#    income_gap_ratio_1000  income_gap_ratio_2000  income_gap_ratio_3000  \
# 0              44.594189              67.521491              78.197199
# 1              47.190314              68.508087              78.074667
# 2              42.284613              64.592824              75.371954
# 3              38.812218              61.817633              73.565824
# 4              40.304690              62.730403              74.154398
#
#    income_gap_ratio_4000  income_gap_ratio_40_median  \
# 0              83.622043                   14.918901
# 1              83.420640                   17.397350
# 2              81.311982                   16.874401
# 3              79.738990                   15.435311
# 4              80.438982                   19.918155
#
#    income_gap_ratio_50_median  income_gap_ratio_60_median  \
# 0                   17.251307                   19.755815
# 1                   18.694320                   20.637824
# 2                   20.327035                   21.971557
# 3                   16.524554                   19.237137
# 4                   20.942427                   21.693936
#
#    poverty_gap_index_international_povline  \
# 0                                 0.140051
# 1                                 0.261761
# 2                                 0.131325
# 3                                 0.051241
# 4                                 0.169101
#
#    poverty_gap_index_lower_mid_income_povline  \
# 0                                    2.094832
# 1                                    2.855918
# 2                                    1.761581
# 3                                    0.751037
# 4                                    1.272609
#
#    poverty_gap_index_upper_mid_income_povline  poverty_gap_index_100  \
# 0                                   12.842785               0.011726
# 1                                   15.095426               0.024816
# 2                                   10.613009               0.000230
# 3                                    7.394906               0.000000
# 4                                    8.645555               0.011959
#
#    poverty_gap_index_1000  poverty_gap_index_2000  poverty_gap_index_3000  \
# 0               38.429134               67.273063               78.128753
# 1               40.271426               67.192763               77.792335
# 2               33.822248               63.027490               74.945700
# 3               29.439467               60.024798               72.841826
# 4               31.062755               61.333158               73.871346
#
#    poverty_gap_index_4000      mean    median  decile1_avg  decile2_avg  \
# 0               83.581605  6.570821  5.774805     2.538496     3.475535
# 1               83.289726  6.715828  5.539607     2.346511     3.263519
# 2               81.110125  7.591930  6.460357     2.643917     3.735312
# 3               79.482429  8.314345  6.957659     3.104265     4.270897
# 4               80.347266  7.882867  6.825289     2.884756     4.093648
#
#    decile3_avg  decile4_avg  decile5_avg  decile6_avg  decile7_avg  \
# 0     4.191319     4.811182     5.506126     6.146939     7.111657
# 1     3.923426     4.525262     5.139692     5.936429     6.869341
# 2     4.537911     5.254513     6.064554     6.860879     7.874459
# 3     5.062166     5.806393     6.578375     7.419832     8.562724
# 4     4.842953     5.542227     6.372377     7.297124     8.289193
#
#    decile8_avg  decile9_avg  decile10_avg  decile1_share  decile2_share  \
# 0     8.196356     9.790226     13.940373       3.863286       5.289347
# 1     8.048536    10.023425     17.082135       3.494002       4.859444
# 2     9.206284    11.261826     18.479644       3.482536       4.920109
# 3     9.918245    12.085071     20.335484       3.733625       5.136781
# 4     9.690645    11.736908     18.078834       3.659527       5.193095
#
#    decile3_share  decile4_share  decile5_share  decile6_share  decile7_share  \
# 0       6.378683       7.322042       8.379662       9.354903      10.823087
# 1       5.842059       6.738204       7.653102       8.839459      10.228585
# 2       5.977283       6.921183       7.988158       9.037069      10.372144
# 3       6.088472       6.983584       7.912079       8.924133      10.298735
# 4       6.143644       7.030726       8.083833       9.256943      10.515455
#
#    decile8_share  decile9_share  decile10_share  decile1_thr  decile2_thr  \
# 0      12.473870      14.899548       21.215573         3.06         3.88
# 1      11.984429      14.925078       25.435637         2.91         3.62
# 2      12.126408      14.833943       24.341168         3.30         4.18
# 3      11.929076      14.535204       24.458311         3.81         4.70
# 4      12.293301      14.889137       22.934340         3.65         4.49
#
#    decile3_thr  decile4_thr  decile6_thr  decile7_thr  decile8_thr  \
# 0         4.48         5.16         6.66         7.61         8.85
# 1         4.22         4.85         6.35         7.38         8.83
# 2         4.93         5.63         7.32         8.51        10.02
# 3         5.43         6.20         7.93         9.24        10.74
# 4         5.17         5.93         7.74         8.91        10.52
#
#    decile9_thr      gini       mld  polarization  palma_ratio  s80_s20_ratio  \
# 0        10.92  0.270103  0.119104      0.241293     0.928335       3.945872
# 1        11.58  0.317390  0.164812      0.268982     1.215056       4.831625
# 2        12.78  0.305957  0.154413      0.254529     1.142718       4.662236
# 3        13.62  0.299847  0.148893      0.247311     1.114657       4.395911
# 4        13.26  0.289605  0.138417      0.249988     1.041193       4.272573
#
#    p90_p10_ratio  p90_p50_ratio  p50_p10_ratio
# 0       3.568627       1.889273       1.888889
# 1       3.979381       2.090253       1.903780
# 2       3.872727       1.978328       1.957576
# 3       3.574803       1.956897       1.826772
# 4       3.632877       1.941435       1.871233
